# %% [markdown]
# ##Question 1

# %%
import pandas as pd

# %%
data = {'Hours':[5, 2, 1, 4, 3], 'Grade Points':[9, 6, 4, 7, 5.6]}

# Create DataFrame
df = pd.DataFrame(data)

# Print the output.
print(df)
# Out:
#    Hours  Grade Points
# 0      5           9.0
# 1      2           6.0
# 2      1           4.0
# 3      4           7.0
# 4      3           5.6

# %%
import seaborn as sns

# %%
sns.lineplot(x = 'Hours', y = 'Grade Points', data=df)
# Out:
# <Axes: xlabel='Hours', ylabel='Grade Points'>

# %% [markdown]
# ![graph.png](data:image/png;base64,...)

# %% [markdown]
# How does studying affect grades?
#
# *   Studying overall appears to increase your grade
# *   from one to two hours your grade will drastically improve
# *   There is a drop in grade from two hours to three hours but it is still higher than if you didn't study
# *   From three hours on the student's grade drastically increases

# %% [markdown]
# ##Question 2

# %% [markdown]
# Problem Statement:
#
# - Predict the probability of a customer
# being a potential defaulter based on past transaction data and historical
# information about customers who have defaulted/not defaulted in their
# payments

# %% [markdown]
# i) What type of Machine Learning does this problem belong to? How?
#
# *  Model-Based Learning
#       - I believe it is model based learning because to do this I would be building a model of the default/not default data to make the predictions using the training data

# %% [markdown]
# ii) Referring to the Week 1 topic Formal Learning stages (slides 17-21), list
# all the steps required to implement the ML solution. (ML algorithm name
# not required)
#
# 1.   Determine type of classification (binary or multi-class)
# 2.   Since it is binary, we will then sort into either potential defaulter and maintained customer using the discriminant

# %% [markdown]
# iii) If your ML solution doesn't perform as expected, what do you think
# might be the reason? Any ideas about how to deal with a model like
# that?
#
# *   I would readjust the discriminant equation to be either broader or more precise depending on the output

# %% [markdown]
# ##Question 3

# %% [markdown]
# Give four examples of clustering (different from the ones given in slides)
# and mention when it is useful.
#
# 1.   Churn/Not Churning
#
#   *   to determine if a customer is going to go to another company or stick with yours
#
# 2.   Underweight/Healthy Weight/Overweight/Obese
#   *   for medical professionals to give a more accurate estimate of what category of weight someone is in
# 3.   Important/Not Important
#   *  for emails to determine if it is essential or just an ad
# 4.   Sick/Healthy
#   *  important for clinical research to determine if someone has the illness of choice or not

# %% [markdown]
# ##Question 4

# %% [markdown]
# What are the names of the two loss functions Ls and LD that we
# discussed in week#2 class time? Explain in detail with examples. What is
# the topic connecting these two loss functions and give the equation for
# the same? (Your answer must be at least 150 words)
#
# *   Empirical Loss: average loss over the data points and used to train a parameterized prediction model. This coincides with ERM (empirical risk minimization), which is how predictors learn from the data. There are concerns however, for example loss cannot be zero or less, this leads to overfitting. This indicates that it works great for the model but not in application. It can also be subject to inductive bias. This is the set of assumptions that a machine learning algorithm makes about the target function it is trying to learn.
#
# ![image.png](data:image/png;base64,...)
#
# *   Loss Function:"The loss quantifies how well the y hat(prediction) approximates y (true label)". By using the two variable function it creates a formula for the overall loss. Loss is overall defined though by how well y hat predicts y. Examples of this include quadratic loss and absolute loss. The equation is l:Rm x Rm → R
